# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Solved by: Rukhshan Alam

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df = pd.read_csv(url, sep = '\t' )

# %%
chipo = df

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price_float'] = chipo.item_price.str.slice(1).astype(float)

# %%
(chipo['item_price_float'] > 10).sum()
# Out:
# 1130

# %%
chipo['price_per_item'] = chipo.item_price_float / chipo.quantity
chipo.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
product_price = chipo.groupby('item_name').agg({'price_per_item' : 'max'})

# %%
product_price.head()
# Out:
#                        price_per_item
# item_name
# 6 Pack Soft Drink                6.49
# Barbacoa Bowl                   11.75
# Barbacoa Burrito                11.75
# Barbacoa Crispy Tacos           11.75
# Barbacoa Salad Bowl             11.89

# %%
(product_price.price_per_item > 10).sum()
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
product_price
# Out:
#                                        price_per_item
# item_name
# 6 Pack Soft Drink                                6.49
# Barbacoa Bowl                                   11.75
# Barbacoa Burrito                                11.75
# Barbacoa Crispy Tacos                           11.75
# Barbacoa Salad Bowl                             11.89
# Barbacoa Soft Tacos                             11.75
# Bottled Water                                    1.50
# Bowl                                             7.40
# Burrito                                          7.40
# Canned Soda                                      1.09
# Canned Soft Drink                                1.25
# Carnitas Bowl                                   11.75
# Carnitas Burrito                                11.75
# Carnitas Crispy Tacos                           11.75
# Carnitas Salad                                   8.99
# Carnitas Salad Bowl                             11.89
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
product_price.sort_index()
# Out:
#                                        price_per_item
# item_name
# 6 Pack Soft Drink                                6.49
# Barbacoa Bowl                                   11.75
# Barbacoa Burrito                                11.75
# Barbacoa Crispy Tacos                           11.75
# Barbacoa Salad Bowl                             11.89
# Barbacoa Soft Tacos                             11.75
# Bottled Water                                    1.50
# Bowl                                             7.40
# Burrito                                          7.40
# Canned Soda                                      1.09
# Canned Soft Drink                                1.25
# Carnitas Bowl                                   11.75
# Carnitas Burrito                                11.75
# Carnitas Crispy Tacos                           11.75
# Carnitas Salad                                   8.99
# Carnitas Salad Bowl                             11.89
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.item_price_float.idxmax()
# Out:
# 3598

# %%
chipo.loc[3598]
# Out:
# order_id                                      1443
# quantity                                        15
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                 $44.25
# item_price_float                             44.25
# price_per_item                                2.95
# Name: 3598, dtype: object

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
(chipo[chipo['item_name'] == 'Veggie Salad Bowl'].quantity).sum()
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
(chipo[chipo['item_name'] == 'Canned Soda'].quantity > 1).sum()
# Out:
# 20
